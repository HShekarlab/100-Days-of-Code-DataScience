# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.lineplot(data= df, x= "sepal_length", y= "sepal_width")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.lineplot(data= df, x= "sepal_length", y= "sepal_width")
plt.title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
sns.lineplot(data= df, x= "sepal_length", y= "sepal_width")
plt.xlim(6)
# Out:
# (6.0, 8.08)

# %%
sns.lineplot(data= df, x= "sepal_length", y= "sepal_width")
plt.ylim(3)
# Out:
# (3.0, 4.00625)

# %%
sns.lineplot(data= df, x= "sepal_length", y= "sepal_width")
sns.set_style("dark")

# %%
sns.lineplot(data= df, x= "sepal_length", y= "sepal_width")
sns.despine()

# %%
plt.figure(figsize= (4, 4))
sns.lineplot(data= df, x= "sepal_length", y= "sepal_width")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.lineplot(data= df, x= "sepal_length", y= "sepal_width")
sns.set_context("paper")

# %%
def plot():
    sns.lineplot(data= df, x= "sepal_length", y= "sepal_width")

with sns.axes_style("darkgrid"):
    plt.subplot(2, 1, 1) # plt.subplot(211)
    plot()

plt.subplot(2, 1, 2) # plt.subplot(212)
plot()

# %%
palette = sns.color_palette()
sns.palplot(palette)

# %%
palette = sns.color_palette("PiYG")
sns.palplot(palette)

# %%
palette = sns.color_palette("PiYG", 8)
sns.palplot(palette)

# %%
palette = sns.color_palette("Greens")
sns.palplot(palette)

# %%
palette = sns.color_palette("Greens", 9)
sns.palplot(palette)

# %%
def plot(): 
    sns.lineplot(data= df, x= "sepal_length", y= "sepal_width")  
    
sns.set_palette("vlag") 
plt.subplot(2, 1, 1) 
plot() 

sns.set_palette("Accent") 
plt.subplot(2, 1, 2) 
plot()

# %%
def Graph(): 
    sns.lineplot(data= df, x= "sepal_length", y= "sepal_width") 

fig = plt.figure(figsize =(8, 4)) 

axes_1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) 
Graph() 

axes_2 = fig.add_axes([0.5, 0.5, 0.3, 0.3]) 
Graph()

# %%
def Graph(): 
    sns.lineplot(data= df, x= "sepal_length", y= "sepal_width") 

plt.subplot(1, 2, 1) 
Graph() 

plt.subplot(1, 2, 2) 
Graph()

# %%
def Graph(): 
    sns.lineplot(data= df, x= "sepal_length", y= "sepal_width") 

axes_1 = plt.subplot2grid ( (7, 1), (0, 0), rowspan = 2, colspan = 1) 
Graph() 

axes_2 = plt.subplot2grid ( (7, 1), (2, 0), rowspan = 2, colspan = 1) 
Graph() 

axes_3 = plt.subplot2grid ( (7, 1), (4, 0), rowspan = 2, colspan = 1) 
Graph()

# %%
plot = sns.FacetGrid(data= df, col= "species") 
plot.map(plt.plot, "sepal_width")

# %%
df = sns.load_dataset("flights") 

plot = sns.PairGrid(df) 
plot.map(plt.plot)
