# %%
import pandas as pd

# %%
df = pd.read_csv("SearchTrendData.csv")

# %%
df.head()
# Out:
#          Week  eLearning  DataScience  MachineLearning  \
# 0  20/09/2015         32            9               11
# 1  27/09/2015         35           10               11
# 2   4/10/2015         38           10               12
# 3  11/10/2015         37            9               12
# 4  18/10/2015         38            9               12
#
#    ArtificialIntelligence  DeepLearning
# 0                      11             4
# 1                      11             4
# 2                      11             4
# 3                      10             4
# 4                      10             4

# %%
df.plot()
# Out:
# <Axes: >

# %%
df[:30].plot.bar()
# Out:
# <Axes: >

# %%
df[:30].plot.bar(stacked= True)
# Out:
# <Axes: >

# %%
df[:30].plot.barh()
# Out:
# <Axes: >

# %%
df[:30].plot.barh(stacked= True)
# Out:
# <Axes: >

# %%
df.plot.area()
# Out:
# <Axes: >

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.plot.box(vert= False)
# Out:
# <Axes: >

# %%
df.plot.scatter(x= "DataScience", y= "MachineLearning")
# Out:
# <Axes: xlabel='DataScience', ylabel='MachineLearning'>
